# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

# %%
#Create a set of 2,000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 755

# %%
#Import dependencies
import requests
from file import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tumaco
# Processing Record 2 of Set 1 | livingstonia
# Processing Record 3 of Set 1 | fairbanks
# Processing Record 4 of Set 1 | souillac
# Processing Record 5 of Set 1 | jian
# Processing Record 6 of Set 1 | saltpond
# Processing Record 7 of Set 1 | ixtapa
# Processing Record 8 of Set 1 | praia da vitoria
# Processing Record 9 of Set 1 | puerto ayora
# Processing Record 10 of Set 1 | albany
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | cabedelo
# Processing Record 14 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 1 | stokmarknes
# Processing Record 16 of Set 1 | kenai
# Processing Record 17 of Set 1 | merauke
# Processing Record 18 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 1 | esperance
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | castro
# Processing Record 22 of Set 1 | ternate
# Processing Record 23 of Set 1 | inirida
# Processing Record 24 of Set 1 | alta floresta
# Processing Record 25 of Set 1 | vaini
# Processing Record 26 of Set 1 | bhongir
# Processing Record 27 of Set 1 | cape town
# Processing Record 28 of Set 1 | mataura
# Processing Record 29 of Set 1 | ribeira grande
# Processing Record 30 of Set 1 | east london
# Processing Record 31 of Set 1 | butaritari
# Processing Record 32 of Set 1 | qaanaaq
# Processing Record 33 of Set 1 | carnarvon
# Processing Record 34 of Set 1 | kuna
# Processing Record 35 of Set 1 | madinat sittah uktubar
# Processing Record 36 of Set 1 | deputatskiy
# Processing Record 37 of Set 1 | bilibino
# Processing Record 38 of Set 1 | lebu
# Processing Record 39 of Set 1 | kapoeta
# Processing Record 40 of Set 1 | vao
# Processing Record 41 of Set 1 | hilo
# Processing Record 42 of Set 1 | hermanus
# Processing Record 43 of Set 1 | hays
# Processing Record 44 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 1 | karpathos
# Processing Record 46 of Set 1 | ahuimanu
# Processing Record 47 of Set 1 | akkudah
# City not found. Skipping...
# Processing Record 48 of Set 1 | dillon
# Processing Record 49 of Set 1 | saint-philippe
# Processing Record 50 of Set 1 | rundu
# Processing Record 1 of Set 2 | ponta do sol
# Processing Record 2 of Set 2 | vila velha
# Processing Record 3 of Set 2 | atar
# Processing Record 4 of Set 2 | ayan
# Processing Record 5 of Set 2 | sao filipe
# Processing Record 6 of Set 2 | auki
# Processing Record 7 of Set 2 | tiksi
# Processing Record 8 of Set 2 | nikolskoye
# Processing Record 9 of Set 2 | kudahuvadhoo
# Processing Record 10 of Set 2 | cornwall
# Processing Record 11 of Set 2 | barrow
# Processing Record 12 of Set 2 | anadyr
# Processing Record 13 of Set 2 | bluff
# Processing Record 14 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 15 of Set 2 | tasiilaq
# Processing Record 16 of Set 2 | bethel
# Processing Record 17 of Set 2 | nyuksenitsa
# Processing Record 18 of Set 2 | ushuaia
# Processing Record 19 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 20 of Set 2 | marystown
# Processing Record 21 of Set 2 | kavieng
# Processing Record 22 of Set 2 | port alfred
# Processing Record 23 of Set 2 | nome
# Processing Record 24 of Set 2 | avarua
# Processing Record 25 of Set 2 | vila franca do campo
# Processing Record 26 of Set 2 | havre-saint-pierre
# Processing Record 27 of Set 2 | bambanglipuro
# Processing Record 28 of Set 2 | ondorhaan
# City not found. Skipping...
# Processing Record 29 of Set 2 | hobart
# Processing Record 30 of Set 2 | roma
# Processing Record 31 of Set 2 | caravelas
# Processing Record 32 of Set 2 | namie
# Processing Record 33 of Set 2 | kavaratti
# Processing Record 34 of Set 2 | port lincoln
# Processing Record 35 of Set 2 | tshikapa
# Processing Record 36 of Set 2 | rocha
# Processing Record 37 of Set 2 | tynda
# Processing Record 38 of Set 2 | port elizabeth
# Processing Record 39 of Set 2 | atuona
# Processing Record 40 of Set 2 | yellowknife
# Processing Record 41 of Set 2 | najran
# Processing Record 42 of Set 2 | haines junction
# Processing Record 43 of Set 2 | chuy
# Processing Record 44 of Set 2 | longyearbyen
# Processing Record 45 of Set 2 | curumani
# Processing Record 46 of Set 2 | victor harbor
# Processing Record 47 of Set 2 | sitka
# Processing Record 48 of Set 2 | dikson
# Processing Record 49 of Set 2 | saint-augustin
# Processing Record 50 of Set 2 | tautira
# Processing Record 1 of Set 3 | yumen
# Processing Record 2 of Set 3 | siniscola
# Processing Record 3 of Set 3 | korla
# Processing Record 4 of Set 3 | alice springs
# Processing Record 5 of Set 3 | sohagpur
# Processing Record 6 of Set 3 | lompoc
# Processing Record 7 of Set 3 | kapaa
# Processing Record 8 of Set 3 | guerrero negro
# Processing Record 9 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 3 | geraldton
# Processing Record 11 of Set 3 | evanston
# Processing Record 12 of Set 3 | lobatse
# Processing Record 13 of Set 3 | pangnirtung
# Processing Record 14 of Set 3 | shchelyayur
# City not found. Skipping...
# Processing Record 15 of Set 3 | mitchell
# Processing Record 16 of Set 3 | mar del plata
# Processing Record 17 of Set 3 | clemson
# Processing Record 18 of Set 3 | kalmunai
# Processing Record 19 of Set 3 | codrington
# Processing Record 20 of Set 3 | maniwaki
# Processing Record 21 of Set 3 | abha
# Processing Record 22 of Set 3 | mehamn
# Processing Record 23 of Set 3 | jadu
# Processing Record 24 of Set 3 | ancud
# Processing Record 25 of Set 3 | erenhot
# Processing Record 26 of Set 3 | mezhdurechensk
# Processing Record 27 of Set 3 | thompson
# Processing Record 28 of Set 3 | antofagasta
# Processing Record 29 of Set 3 | bambous virieux
# Processing Record 30 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 31 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 32 of Set 3 | klaksvik
# Processing Record 33 of Set 3 | vostok
# Processing Record 34 of Set 3 | huarmey
# Processing Record 35 of Set 3 | gat
# Processing Record 36 of Set 3 | pevek
# Processing Record 37 of Set 3 | port-gentil
# Processing Record 38 of Set 3 | haimen
# Processing Record 39 of Set 3 | geylegphug
# City not found. Skipping...
# Processing Record 40 of Set 3 | oranjemund
# Processing Record 41 of Set 3 | letlhakane
# Processing Record 42 of Set 3 | lithakia
# Processing Record 43 of Set 3 | berlevag
# Processing Record 44 of Set 3 | ust-ishim
# Processing Record 45 of Set 3 | sayat
# Processing Record 46 of Set 3 | martapura
# Processing Record 47 of Set 3 | springfield
# Processing Record 48 of Set 3 | jamestown
# Processing Record 49 of Set 3 | ilulissat
# Processing Record 50 of Set 3 | tuktoyaktuk
# Processing Record 1 of Set 4 | hamilton
# Processing Record 2 of Set 4 | indiana
# Processing Record 3 of Set 4 | upernavik
# Processing Record 4 of Set 4 | katherine
# Processing Record 5 of Set 4 | talnakh
# Processing Record 6 of Set 4 | brae
# Processing Record 7 of Set 4 | faya
# Processing Record 8 of Set 4 | tandil
# Processing Record 9 of Set 4 | lavrentiya
# Processing Record 10 of Set 4 | chokurdakh
# Processing Record 11 of Set 4 | honiara
# Processing Record 12 of Set 4 | cumaribo
# City not found. Skipping...
# Processing Record 13 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 14 of Set 4 | mahanoro
# Processing Record 15 of Set 4 | malakal
# Processing Record 16 of Set 4 | wajima
# Processing Record 17 of Set 4 | khuzhir
# Processing Record 18 of Set 4 | nantucket
# Processing Record 19 of Set 4 | georgetown
# Processing Record 20 of Set 4 | haicheng
# Processing Record 21 of Set 4 | portland
# Processing Record 22 of Set 4 | te anau
# Processing Record 23 of Set 4 | eyl
# Processing Record 24 of Set 4 | conceicao da barra
# Processing Record 25 of Set 4 | tucupita
# Processing Record 26 of Set 4 | okhotsk
# Processing Record 27 of Set 4 | zimapan
# Processing Record 28 of Set 4 | bijie
# Processing Record 29 of Set 4 | nelson bay
# Processing Record 30 of Set 4 | fare
# Processing Record 31 of Set 4 | sangueya
# Processing Record 32 of Set 4 | taoudenni
# Processing Record 33 of Set 4 | namatanai
# Processing Record 34 of Set 4 | itoman
# Processing Record 35 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 36 of Set 4 | jacareacanga
# Processing Record 37 of Set 4 | asosa
# Processing Record 38 of Set 4 | dingle
# Processing Record 39 of Set 4 | nicoya
# Processing Record 40 of Set 4 | lata
# Processing Record 41 of Set 4 | bloomfield
# Processing Record 42 of Set 4 | moron
# Processing Record 43 of Set 4 | airai
# Processing Record 44 of Set 4 | wynyard
# Processing Record 45 of Set 4 | chebsara
# Processing Record 46 of Set 4 | cidreira
# Processing Record 47 of Set 4 | yeppoon
# Processing Record 48 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 4 | tabas
# Processing Record 50 of Set 4 | new norfolk
# Processing Record 1 of Set 5 | weyburn
# Processing Record 2 of Set 5 | severo-kurilsk
# Processing Record 3 of Set 5 | kiunga
# Processing Record 4 of Set 5 | itarema
# Processing Record 5 of Set 5 | goundi
# Processing Record 6 of Set 5 | akyab
# Processing Record 7 of Set 5 | saint anthony
# Processing Record 8 of Set 5 | oum hadjer
# Processing Record 9 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 10 of Set 5 | tazovskiy
# Processing Record 11 of Set 5 | bredasdorp
# Processing Record 12 of Set 5 | salalah
# Processing Record 13 of Set 5 | bodden town
# Processing Record 14 of Set 5 | gizo
# Processing Record 15 of Set 5 | marawi
# Processing Record 16 of Set 5 | the valley
# Processing Record 17 of Set 5 | pisco
# Processing Record 18 of Set 5 | camapua
# Processing Record 19 of Set 5 | broome
# Processing Record 20 of Set 5 | kodiak
# Processing Record 21 of Set 5 | labrea
# Processing Record 22 of Set 5 | komsomolskiy
# Processing Record 23 of Set 5 | marsh harbour
# Processing Record 24 of Set 5 | masumbwe
# Processing Record 25 of Set 5 | bilma
# Processing Record 26 of Set 5 | englehart
# Processing Record 27 of Set 5 | gonbad-e qabus
# Processing Record 28 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 29 of Set 5 | mirnyy
# Processing Record 30 of Set 5 | adrar
# Processing Record 31 of Set 5 | cabo san lucas
# Processing Record 32 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 5 | torbay
# Processing Record 34 of Set 5 | tuatapere
# Processing Record 35 of Set 5 | snyder
# Processing Record 36 of Set 5 | boda
# Processing Record 37 of Set 5 | ustye
# Processing Record 38 of Set 5 | buala
# Processing Record 39 of Set 5 | burns lake
# Processing Record 40 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 41 of Set 5 | hithadhoo
# Processing Record 42 of Set 5 | hasaki
# Processing Record 43 of Set 5 | bokoro
# Processing Record 44 of Set 5 | arawa
# Processing Record 45 of Set 5 | avonbridge
# Processing Record 46 of Set 5 | gardanne
# Processing Record 47 of Set 5 | provideniya
# Processing Record 48 of Set 5 | coahuayana
# Processing Record 49 of Set 5 | san cristobal
# Processing Record 50 of Set 5 | bokspits
# City not found. Skipping...
# Processing Record 1 of Set 6 | quatre cocos
# Processing Record 2 of Set 6 | manado
# Processing Record 3 of Set 6 | camacha
# Processing Record 4 of Set 6 | we
# City not found. Skipping...
# Processing Record 5 of Set 6 | batemans bay
# Processing Record 6 of Set 6 | macheng
# Processing Record 7 of Set 6 | longyan
# Processing Record 8 of Set 6 | gobabis
# Processing Record 9 of Set 6 | yulara
# Processing Record 10 of Set 6 | dunedin
# Processing Record 11 of Set 6 | jieshi
# Processing Record 12 of Set 6 | chingola
# Processing Record 13 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 14 of Set 6 | pingzhuang
# Processing Record 15 of Set 6 | khatanga
# Processing Record 16 of Set 6 | erzin
# Processing Record 17 of Set 6 | sembakung
# Processing Record 18 of Set 6 | matagami
# Processing Record 19 of Set 6 | bathsheba
# Processing Record 20 of Set 6 | henties bay
# Processing Record 21 of Set 6 | port macquarie
# Processing Record 22 of Set 6 | coihaique
# Processing Record 23 of Set 6 | tura
# Processing Record 24 of Set 6 | phalodi
# Processing Record 25 of Set 6 | turan
# Processing Record 26 of Set 6 | kaitangata
# Processing Record 27 of Set 6 | camana
# Processing Record 28 of Set 6 | purpe
# Processing Record 29 of Set 6 | grindavik
# Processing Record 30 of Set 6 | alotau
# City not found. Skipping...
# Processing Record 31 of Set 6 | diego de almagro
# Processing Record 32 of Set 6 | buin
# Processing Record 33 of Set 6 | antalaha
# Processing Record 34 of Set 6 | sisimiut
# Processing Record 35 of Set 6 | lagoa
# Processing Record 36 of Set 6 | barbar
# City not found. Skipping...
# Processing Record 37 of Set 6 | ugoofaaru
# Processing Record 38 of Set 6 | flinders
# Processing Record 39 of Set 6 | padang
# Processing Record 40 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 41 of Set 6 | lar gerd
# City not found. Skipping...
# Processing Record 42 of Set 6 | tianpeng
# Processing Record 43 of Set 6 | saldanha
# Processing Record 44 of Set 6 | koraput
# Processing Record 45 of Set 6 | laguna
# Processing Record 46 of Set 6 | san patricio
# Processing Record 47 of Set 6 | kaina
# Processing Record 48 of Set 6 | itaituba
# Processing Record 49 of Set 6 | jais
# Processing Record 50 of Set 6 | funtua
# Processing Record 1 of Set 7 | ruwi
# Processing Record 2 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 3 of Set 7 | yarmouth
# Processing Record 4 of Set 7 | belmonte
# Processing Record 5 of Set 7 | sapa
# Processing Record 6 of Set 7 | leningradskiy
# Processing Record 7 of Set 7 | neftcala
# Processing Record 8 of Set 7 | kahului
# Processing Record 9 of Set 7 | tereze
# Processing Record 10 of Set 7 | contamana
# Processing Record 11 of Set 7 | skalistyy
# City not found. Skipping...
# Processing Record 12 of Set 7 | santa luzia
# Processing Record 13 of Set 7 | dandong
# Processing Record 14 of Set 7 | noumea
# Processing Record 15 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 16 of Set 7 | san policarpo
# Processing Record 17 of Set 7 | yilan
# Processing Record 18 of Set 7 | onda
# Processing Record 19 of Set 7 | praya
# Processing Record 20 of Set 7 | baft
# Processing Record 21 of Set 7 | abnub
# Processing Record 22 of Set 7 | teahupoo
# Processing Record 23 of Set 7 | lorengau
# Processing Record 24 of Set 7 | tsagan aman
# Processing Record 25 of Set 7 | aasiaat
# Processing Record 26 of Set 7 | grand gaube
# Processing Record 27 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 28 of Set 7 | harper
# Processing Record 29 of Set 7 | lodja
# Processing Record 30 of Set 7 | boyolangu
# Processing Record 31 of Set 7 | north bend
# Processing Record 32 of Set 7 | cravinhos
# Processing Record 33 of Set 7 | waterloo
# Processing Record 34 of Set 7 | faanui
# Processing Record 35 of Set 7 | olga
# Processing Record 36 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 37 of Set 7 | kalat
# Processing Record 38 of Set 7 | qostanay
# Processing Record 39 of Set 7 | prado
# Processing Record 40 of Set 7 | coquimbo
# Processing Record 41 of Set 7 | muroto
# Processing Record 42 of Set 7 | kruisfontein
# Processing Record 43 of Set 7 | labuhan
# Processing Record 44 of Set 7 | taunggyi
# Processing Record 45 of Set 7 | matay
# Processing Record 46 of Set 7 | the village
# Processing Record 47 of Set 7 | bid
# City not found. Skipping...
# Processing Record 48 of Set 7 | vinh
# Processing Record 49 of Set 7 | hay river
# Processing Record 50 of Set 7 | sol-iletsk
# Processing Record 1 of Set 8 | reconquista
# Processing Record 2 of Set 8 | norman wells
# Processing Record 3 of Set 8 | arraial do cabo
# Processing Record 4 of Set 8 | acarau
# Processing Record 5 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 8 | taltal
# Processing Record 7 of Set 8 | nha trang
# Processing Record 8 of Set 8 | prince rupert
# Processing Record 9 of Set 8 | galiwinku
# City not found. Skipping...
# Processing Record 10 of Set 8 | ambilobe
# Processing Record 11 of Set 8 | san felice sul panaro
# Processing Record 12 of Set 8 | tabou
# Processing Record 13 of Set 8 | iqaluit
# Processing Record 14 of Set 8 | kautokeino
# Processing Record 15 of Set 8 | solovetskiy
# City not found. Skipping...
# Processing Record 16 of Set 8 | champerico
# Processing Record 17 of Set 8 | rehoboth
# Processing Record 18 of Set 8 | sur
# Processing Record 19 of Set 8 | nanortalik
# Processing Record 20 of Set 8 | xichang
# Processing Record 21 of Set 8 | lages
# Processing Record 22 of Set 8 | paradwip
# City not found. Skipping...
# Processing Record 23 of Set 8 | vardo
# Processing Record 24 of Set 8 | hervey bay
# Processing Record 25 of Set 8 | gornopravdinsk
# Processing Record 26 of Set 8 | baruun-urt
# Processing Record 27 of Set 8 | sobolevo
# Processing Record 28 of Set 8 | port hedland
# Processing Record 29 of Set 8 | bengkulu
# Processing Record 30 of Set 8 | ivaipora
# Processing Record 31 of Set 8 | kohlu
# Processing Record 32 of Set 8 | khandyga
# Processing Record 33 of Set 8 | tupik
# Processing Record 34 of Set 8 | yerbogachen
# Processing Record 35 of Set 8 | tutoia
# Processing Record 36 of Set 8 | tambura
# Processing Record 37 of Set 8 | saskylakh
# Processing Record 38 of Set 8 | hualmay
# Processing Record 39 of Set 8 | sihor
# Processing Record 40 of Set 8 | narsaq
# Processing Record 41 of Set 8 | badou
# Processing Record 42 of Set 8 | pitsunda
# Processing Record 43 of Set 8 | cascais
# Processing Record 44 of Set 8 | dwarka
# Processing Record 45 of Set 8 | kholtoson
# Processing Record 46 of Set 8 | tursunzoda
# Processing Record 47 of Set 8 | surt
# Processing Record 48 of Set 8 | namibe
# Processing Record 49 of Set 8 | lasa
# Processing Record 50 of Set 8 | saint george
# Processing Record 1 of Set 9 | gemena
# Processing Record 2 of Set 9 | muros
# Processing Record 3 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 4 of Set 9 | mukacheve
# Processing Record 5 of Set 9 | batagay-alyta
# Processing Record 6 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 7 of Set 9 | qinzhou
# Processing Record 8 of Set 9 | kitimat
# Processing Record 9 of Set 9 | havelock
# Processing Record 10 of Set 9 | margate
# Processing Record 11 of Set 9 | luderitz
# Processing Record 12 of Set 9 | garowe
# Processing Record 13 of Set 9 | isangel
# Processing Record 14 of Set 9 | whitianga
# Processing Record 15 of Set 9 | poum
# Processing Record 16 of Set 9 | pinheiro
# Processing Record 17 of Set 9 | tuni
# Processing Record 18 of Set 9 | tofield
# Processing Record 19 of Set 9 | shahr-e kord
# Processing Record 20 of Set 9 | sladkovo
# Processing Record 21 of Set 9 | puerto escondido
# Processing Record 22 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 23 of Set 9 | cockburn town
# Processing Record 24 of Set 9 | vung tau
# Processing Record 25 of Set 9 | aron
# Processing Record 26 of Set 9 | isla vista
# Processing Record 27 of Set 9 | krasnoselkup
# Processing Record 28 of Set 9 | ouargaye
# Processing Record 29 of Set 9 | richmond
# Processing Record 30 of Set 9 | fortuna
# Processing Record 31 of Set 9 | mikun
# Processing Record 32 of Set 9 | fevralsk
# City not found. Skipping...
# Processing Record 33 of Set 9 | qiryat gat
# Processing Record 34 of Set 9 | artyk
# City not found. Skipping...
# Processing Record 35 of Set 9 | humaita
# Processing Record 36 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 37 of Set 9 | marang
# Processing Record 38 of Set 9 | saint peters
# Processing Record 39 of Set 9 | usinsk
# Processing Record 40 of Set 9 | maksatikha
# Processing Record 41 of Set 9 | kropotkin
# Processing Record 42 of Set 9 | achisay
# City not found. Skipping...
# Processing Record 43 of Set 9 | sioux lookout
# Processing Record 44 of Set 9 | tempio pausania
# Processing Record 45 of Set 9 | shache
# Processing Record 46 of Set 9 | wageningen
# Processing Record 47 of Set 9 | kijang
# Processing Record 48 of Set 9 | vestmannaeyjar
# Processing Record 49 of Set 9 | versalles
# Processing Record 50 of Set 9 | cabudare
# Processing Record 1 of Set 10 | chapais
# Processing Record 2 of Set 10 | port blair
# Processing Record 3 of Set 10 | kangaatsiaq
# Processing Record 4 of Set 10 | bacong
# Processing Record 5 of Set 10 | lazaro cardenas
# Processing Record 6 of Set 10 | nabire
# Processing Record 7 of Set 10 | kuala terengganu
# Processing Record 8 of Set 10 | omsukchan
# Processing Record 9 of Set 10 | awjilah
# Processing Record 10 of Set 10 | mlyniv
# Processing Record 11 of Set 10 | katsuura
# Processing Record 12 of Set 10 | yar-sale
# Processing Record 13 of Set 10 | beringovskiy
# Processing Record 14 of Set 10 | tottori
# Processing Record 15 of Set 10 | sangin
# Processing Record 16 of Set 10 | ghanzi
# Processing Record 17 of Set 10 | one hundred mile house
# City not found. Skipping...
# Processing Record 18 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 19 of Set 10 | montlucon
# Processing Record 20 of Set 10 | tual
# Processing Record 21 of Set 10 | road town
# Processing Record 22 of Set 10 | olafsvik
# Processing Record 23 of Set 10 | ukholovo
# Processing Record 24 of Set 10 | tsienyane
# City not found. Skipping...
# Processing Record 25 of Set 10 | baykit
# Processing Record 26 of Set 10 | ulladulla
# Processing Record 27 of Set 10 | saint-paul
# Processing Record 28 of Set 10 | severo-yeniseyskiy
# Processing Record 29 of Set 10 | pimentel
# Processing Record 30 of Set 10 | luganville
# Processing Record 31 of Set 10 | puerto del rosario
# Processing Record 32 of Set 10 | guadalupe victoria
# Processing Record 33 of Set 10 | half moon bay
# Processing Record 34 of Set 10 | at-bashi
# Processing Record 35 of Set 10 | port hardy
# Processing Record 36 of Set 10 | ostrovnoy
# Processing Record 37 of Set 10 | elk city
# Processing Record 38 of Set 10 | zalesovo
# Processing Record 39 of Set 10 | alyangula
# Processing Record 40 of Set 10 | bela
# Processing Record 41 of Set 10 | santa maria del oro
# Processing Record 42 of Set 10 | clyde river
# Processing Record 43 of Set 10 | keti bandar
# Processing Record 44 of Set 10 | whitehorse
# Processing Record 45 of Set 10 | srednekolymsk
# Processing Record 46 of Set 10 | joshimath
# Processing Record 47 of Set 10 | kusadak
# Processing Record 48 of Set 10 | atlantic city
# Processing Record 49 of Set 10 | platanos
# Processing Record 50 of Set 10 | zaragoza
# Processing Record 1 of Set 11 | saryagash
# Processing Record 2 of Set 11 | havoysund
# Processing Record 3 of Set 11 | ust-uda
# Processing Record 4 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 5 of Set 11 | touros
# Processing Record 6 of Set 11 | evensk
# Processing Record 7 of Set 11 | corinto
# Processing Record 8 of Set 11 | chengdu
# Processing Record 9 of Set 11 | khasan
# Processing Record 10 of Set 11 | edd
# Processing Record 11 of Set 11 | victoria
# Processing Record 12 of Set 11 | nambour
# Processing Record 13 of Set 11 | nemuro
# Processing Record 14 of Set 11 | kaspiysk
# Processing Record 15 of Set 11 | hauterive
# Processing Record 16 of Set 11 | arkhangelsk
# Processing Record 17 of Set 11 | emerald
# Processing Record 18 of Set 11 | dali
# Processing Record 19 of Set 11 | toamasina
# Processing Record 20 of Set 11 | nouadhibou
# Processing Record 21 of Set 11 | jiayuguan
# Processing Record 22 of Set 11 | kasama
# Processing Record 23 of Set 11 | kaeo
# Processing Record 24 of Set 11 | walvis bay
# Processing Record 25 of Set 11 | luau
# Processing Record 26 of Set 11 | northam
# Processing Record 27 of Set 11 | richards bay
# Processing Record 28 of Set 11 | tapah
# Processing Record 29 of Set 11 | aklavik
# Processing Record 30 of Set 11 | gamba
# Processing Record 31 of Set 11 | maykain
# City not found. Skipping...
# Processing Record 32 of Set 11 | hammerfest
# Processing Record 33 of Set 11 | ulaangom
# Processing Record 34 of Set 11 | ayabaca
# Processing Record 35 of Set 11 | canico
# Processing Record 36 of Set 11 | yangambi
# Processing Record 37 of Set 11 | paamiut
# Processing Record 38 of Set 11 | panguna
# Processing Record 39 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 40 of Set 11 | pedasi
# Processing Record 41 of Set 11 | la garriga
# Processing Record 42 of Set 11 | orlik
# Processing Record 43 of Set 11 | shakiso
# Processing Record 44 of Set 11 | owando
# Processing Record 45 of Set 11 | pindiga
# Processing Record 46 of Set 11 | bima
# Processing Record 47 of Set 11 | netanya
# Processing Record 48 of Set 11 | kaitong
# Processing Record 49 of Set 11 | kalinagar
# Processing Record 50 of Set 11 | bubaque
# Processing Record 1 of Set 12 | marsa matruh
# Processing Record 2 of Set 12 | bezhetsk
# Processing Record 3 of Set 12 | kuantan
# Processing Record 4 of Set 12 | salta
# Processing Record 5 of Set 12 | lamar
# Processing Record 6 of Set 12 | sinegorskiy
# Processing Record 7 of Set 12 | san jose
# Processing Record 8 of Set 12 | derzhavinsk
# Processing Record 9 of Set 12 | veraval
# Processing Record 10 of Set 12 | brookhaven
# Processing Record 11 of Set 12 | tanout
# Processing Record 12 of Set 12 | belyy yar
# Processing Record 13 of Set 12 | limon
# Processing Record 14 of Set 12 | manga
# Processing Record 15 of Set 12 | poya
# Processing Record 16 of Set 12 | ituni
# City not found. Skipping...
# Processing Record 17 of Set 12 | abay
# Processing Record 18 of Set 12 | xining
# Processing Record 19 of Set 12 | chumikan
# Processing Record 20 of Set 12 | ukiah
# Processing Record 21 of Set 12 | nuevo progreso
# Processing Record 22 of Set 12 | krutinka
# Processing Record 23 of Set 12 | sohag
# Processing Record 24 of Set 12 | falealupo
# City not found. Skipping...
# Processing Record 25 of Set 12 | mackay
# Processing Record 26 of Set 12 | oistins
# Processing Record 27 of Set 12 | nyurba
# Processing Record 28 of Set 12 | saint-pierre
# Processing Record 29 of Set 12 | siilinjarvi
# Processing Record 30 of Set 12 | mahebourg
# Processing Record 31 of Set 12 | smithers
# Processing Record 32 of Set 12 | moosomin
# Processing Record 33 of Set 12 | guarapari
# Processing Record 34 of Set 12 | chicama
# Processing Record 35 of Set 12 | parrita
# Processing Record 36 of Set 12 | inuvik
# Processing Record 37 of Set 12 | farafangana
# Processing Record 38 of Set 12 | shaunavon
# Processing Record 39 of Set 12 | grootfontein
# Processing Record 40 of Set 12 | raglan
# Processing Record 41 of Set 12 | naze
# Processing Record 42 of Set 12 | zhangye
# Processing Record 43 of Set 12 | shingu
# Processing Record 44 of Set 12 | colares
# Processing Record 45 of Set 12 | luba
# Processing Record 46 of Set 12 | kuruman
# Processing Record 47 of Set 12 | ambulu
# Processing Record 48 of Set 12 | manzhouli
# Processing Record 49 of Set 12 | avera
# Processing Record 50 of Set 12 | biak
# Processing Record 1 of Set 13 | gazli
# Processing Record 2 of Set 13 | tavda
# Processing Record 3 of Set 13 | wiarton
# Processing Record 4 of Set 13 | trzcianka
# Processing Record 5 of Set 13 | kimbe
# Processing Record 6 of Set 13 | tiznit
# Processing Record 7 of Set 13 | ceres
# Processing Record 8 of Set 13 | kutum
# Processing Record 9 of Set 13 | labutta
# City not found. Skipping...
# Processing Record 10 of Set 13 | cherskiy
# Processing Record 11 of Set 13 | sinnamary
# Processing Record 12 of Set 13 | cayenne
# Processing Record 13 of Set 13 | liverpool
# Processing Record 14 of Set 13 | lebyazhye
# Processing Record 15 of Set 13 | denia
# Processing Record 16 of Set 13 | dumas
# Processing Record 17 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 18 of Set 13 | santa vitoria do palmar
# Processing Record 19 of Set 13 | blackwater
# Processing Record 20 of Set 13 | hami
# Processing Record 21 of Set 13 | uglegorskiy
# Processing Record 22 of Set 13 | huilong
# Processing Record 23 of Set 13 | piet retief
# Processing Record 24 of Set 13 | manoel urbano
# Processing Record 25 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 26 of Set 13 | vikhorevka
# Processing Record 27 of Set 13 | yarada
# Processing Record 28 of Set 13 | blackfalds
# Processing Record 29 of Set 13 | goure
# Processing Record 30 of Set 13 | hengyang
# Processing Record 31 of Set 13 | salinas
# Processing Record 32 of Set 13 | tessalit
# Processing Record 33 of Set 13 | bairiki
# Processing Record 34 of Set 13 | tchaourou
# Processing Record 35 of Set 13 | kadykchan
# City not found. Skipping...
# Processing Record 36 of Set 13 | cacador
# Processing Record 37 of Set 13 | monroe
# Processing Record 38 of Set 13 | beachwood
# Processing Record 39 of Set 13 | larsnes
# Processing Record 40 of Set 13 | bingol
# Processing Record 41 of Set 13 | presidencia roque saenz pena
# Processing Record 42 of Set 13 | bouna
# Processing Record 43 of Set 13 | marquette
# Processing Record 44 of Set 13 | chengde
# Processing Record 45 of Set 13 | chake chake
# Processing Record 46 of Set 13 | seoul
# Processing Record 47 of Set 13 | la ronge
# Processing Record 48 of Set 13 | la asuncion
# Processing Record 49 of Set 13 | tukrah
# Processing Record 50 of Set 13 | marienburg
# Processing Record 1 of Set 14 | kieta
# Processing Record 2 of Set 14 | olinda
# Processing Record 3 of Set 14 | katobu
# Processing Record 4 of Set 14 | lahat
# Processing Record 5 of Set 14 | juifang
# City not found. Skipping...
# Processing Record 6 of Set 14 | santa cruz de la palma
# Processing Record 7 of Set 14 | senno
# Processing Record 8 of Set 14 | moroni
# Processing Record 9 of Set 14 | mogadishu
# Processing Record 10 of Set 14 | constantine
# Processing Record 11 of Set 14 | rubbestadneset
# Processing Record 12 of Set 14 | marneuli
# Processing Record 13 of Set 14 | maniitsoq
# Processing Record 14 of Set 14 | asau
# Processing Record 15 of Set 14 | qasigiannguit
# Processing Record 16 of Set 14 | aktyubinskiy
# Processing Record 17 of Set 14 | nizwa
# Processing Record 18 of Set 14 | bayshore gardens
# Processing Record 19 of Set 14 | college
# Processing Record 20 of Set 14 | sweetwater
# Processing Record 21 of Set 14 | saratovskaya
# Processing Record 22 of Set 14 | flin flon
# Processing Record 23 of Set 14 | bardiyah
# Processing Record 24 of Set 14 | tommot
# Processing Record 25 of Set 14 | diamantino
# Processing Record 26 of Set 14 | singaraja
# Processing Record 27 of Set 14 | waipawa
# Processing Record 28 of Set 14 | marquard
# Processing Record 29 of Set 14 | acapulco
# Processing Record 30 of Set 14 | camopi
# Processing Record 31 of Set 14 | dipkarpaz
# City not found. Skipping...
# Processing Record 32 of Set 14 | bundaberg
# Processing Record 33 of Set 14 | maragogi
# Processing Record 34 of Set 14 | qunduz
# Processing Record 35 of Set 14 | arlit
# Processing Record 36 of Set 14 | mahajanga
# Processing Record 37 of Set 14 | pascagoula
# Processing Record 38 of Set 14 | qaqortoq
# Processing Record 39 of Set 14 | vila do maio
# Processing Record 40 of Set 14 | curaca
# Processing Record 41 of Set 14 | ottawa
# Processing Record 42 of Set 14 | visegrad
# Processing Record 43 of Set 14 | sindou
# Processing Record 44 of Set 14 | eureka
# Processing Record 45 of Set 14 | anloga
# Processing Record 46 of Set 14 | do rud
# City not found. Skipping...
# Processing Record 47 of Set 14 | zhanakorgan
# Processing Record 48 of Set 14 | alexandria
# Processing Record 49 of Set 14 | taywarah
# Processing Record 50 of Set 14 | clarence town
# Processing Record 1 of Set 15 | takaungu
# Processing Record 2 of Set 15 | teya
# Processing Record 3 of Set 15 | padilla
# Processing Record 4 of Set 15 | suluq
# Processing Record 5 of Set 15 | warrnambool
# Processing Record 6 of Set 15 | cafarnaum
# Processing Record 7 of Set 15 | bhakkar
# Processing Record 8 of Set 15 | ahipara
# Processing Record 9 of Set 15 | micomeseng
# Processing Record 10 of Set 15 | cap malheureux
# Processing Record 11 of Set 15 | bontang
# Processing Record 12 of Set 15 | beloha
# Processing Record 13 of Set 15 | ratnagiri
# Processing Record 14 of Set 15 | hokitika
# Processing Record 15 of Set 15 | belle fourche
# Processing Record 16 of Set 15 | saryshagan
# City not found. Skipping...
# Processing Record 17 of Set 15 | agar
# Processing Record 18 of Set 15 | sumbawa
# City not found. Skipping...
# Processing Record 19 of Set 15 | santo amaro das brotas
# Processing Record 20 of Set 15 | santa fe
# Processing Record 21 of Set 15 | yabrud
# Processing Record 22 of Set 15 | gaoual
# Processing Record 23 of Set 15 | sayanskiy
# City not found. Skipping...
# Processing Record 24 of Set 15 | los llanos de aridane
# Processing Record 25 of Set 15 | perth
# Processing Record 26 of Set 15 | cabcab
# Processing Record 27 of Set 15 | rolim de moura
# City not found. Skipping...
# Processing Record 28 of Set 15 | pochutla
# Processing Record 29 of Set 15 | karratha
# Processing Record 30 of Set 15 | puga
# Processing Record 31 of Set 15 | tiarei
# Processing Record 32 of Set 15 | yelizavetinskoye
# Processing Record 33 of Set 15 | albert
# Processing Record 34 of Set 15 | santa cruz
# Processing Record 35 of Set 15 | kloulklubed
# Processing Record 36 of Set 15 | tilichiki
# Processing Record 37 of Set 15 | mikasa
# Processing Record 38 of Set 15 | puerto maldonado
# Processing Record 39 of Set 15 | makung
# City not found. Skipping...
# Processing Record 40 of Set 15 | karasjok
# Processing Record 41 of Set 15 | hovd
# Processing Record 42 of Set 15 | suclayin
# Processing Record 43 of Set 15 | rafaela
# Processing Record 44 of Set 15 | constitucion
# Processing Record 45 of Set 15 | sangre grande
# Processing Record 46 of Set 15 | homer
# Processing Record 47 of Set 15 | portlethen
# Processing Record 48 of Set 15 | svetlyy
# Processing Record 49 of Set 15 | thai binh
# Processing Record 50 of Set 15 | piracuruca
# Processing Record 1 of Set 16 | along
# Processing Record 2 of Set 16 | kanniyakumari
# Processing Record 3 of Set 16 | tuy hoa
# Processing Record 4 of Set 16 | puerto carreno
# Processing Record 5 of Set 16 | yanan
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 690

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0            Tumaco      CO   1.7986  -78.8156     78.24        88
# 1      Livingstonia      MW -10.6060   34.1063     66.67        86
# 2         Fairbanks      US  64.8378 -147.7164     -7.01        77
# 3          Souillac      MU -20.5167   57.5167     78.80        83
# 4              Jian      CN  27.1172  114.9793     50.40        83
# 5          Saltpond      GH   5.2091   -1.0606     81.16        83
# 6            Ixtapa      MX  20.7000 -105.2000     75.20        64
# 7  Praia Da Vitoria      PT  38.7333  -27.0667     60.80        77
# 8      Puerto Ayora      EC  -0.7393  -90.3518     80.60        83
# 9            Albany      US  42.6001  -73.9662     24.01        46
#
#    Cloudiness  Wind Speed Current Description
# 0          98        4.54          light rain
# 1         100        3.20          light rain
# 2           1       11.50           clear sky
# 3          75        6.91          light rain
# 4         100        7.29     overcast clouds
# 5          28       13.29    scattered clouds
# 6           1       11.50           clear sky
# 7          40       12.50    scattered clouds
# 8          75       10.36       broken clouds
# 9          85        1.23     overcast clouds

# %%
city_data_df.to_csv (r'C:\Users\mikeb\Class\World_Weather_Analysis\Weather_Database\WeatherPy_Database.csv', index_label='City_ID', header=True)
